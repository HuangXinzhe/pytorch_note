# %% [markdown]
# # 损失函数

# %%
import torch
from torch import nn

# %% [markdown]
# ## 二分类交叉熵损失函数
# ![image.png](attachment:image.png)

# %%
torch.nn.BCELoss(weight=None, size_average=None, reduce=None, reduction='mean')
# Out:
# BCELoss()

# %%
m = nn.Sigmoid()
loss = nn.BCELoss()
input = torch.randn(3, requires_grad=True)
target = torch.empty(3).random_(2)
output = loss(m(input), target)
output.backward()

# %%
print('BCELoss损失函数的计算结果为',output)
# Out:
# BCELoss损失函数的计算结果为 tensor(0.4470, grad_fn=<BinaryCrossEntropyBackward0>)

# %% [markdown]
# ## 交叉熵损失函数
# ![image.png](attachment:image.png)

# %%
torch.nn.CrossEntropyLoss(weight=None, size_average=None, ignore_index=-100, reduce=None, reduction='mean')
# Out:
# CrossEntropyLoss()

# %%
loss = nn.CrossEntropyLoss()
input = torch.randn(3, 5, requires_grad=True)
target = torch.empty(3, dtype=torch.long).random_(5)
output = loss(input, target)
output.backward()

# %%
print(output)
# Out:
# tensor(1.9707, grad_fn=<NllLossBackward0>)

# %% [markdown]
# ## L1损失函数
# ![image.png](attachment:image.png)

# %%
torch.nn.L1Loss(size_average=None, reduce=None, reduction='mean')
# Out:
# L1Loss()

# %%
loss = nn.L1Loss()
input = torch.randn(3, 5, requires_grad=True)
target = torch.randn(3, 5)
output = loss(input, target)
output.backward()

# %%
print('L1损失函数的计算结果为',output)
# Out:
# L1损失函数的计算结果为 tensor(1.1367, grad_fn=<MeanBackward0>)

# %% [markdown]
# ## MSE损失函数
# ![image.png](attachment:image.png)

# %%
torch.nn.MSELoss(size_average=None, reduce=None, reduction='mean')
# Out:
# MSELoss()

# %%
loss = nn.MSELoss()
input = torch.randn(3, 5, requires_grad=True)
target = torch.randn(3, 5)
output = loss(input, target)
output.backward()

# %%
print('MSE损失函数的计算结果为',output)
# Out:
# MSE损失函数的计算结果为 tensor(2.6412, grad_fn=<MseLossBackward0>)

# %% [markdown]
# ## 余弦相似度
# ![image.png](attachment:image.png)

# %%
torch.nn.CosineEmbeddingLoss(margin=0.0, size_average=None, reduce=None, reduction='mean')
# Out:
# CosineEmbeddingLoss()

# %%
loss_f = nn.CosineEmbeddingLoss()
inputs_1 = torch.tensor([[0.3, 0.5, 0.7], [0.3, 0.5, 0.7]])
inputs_2 = torch.tensor([[0.1, 0.3, 0.5], [0.1, 0.3, 0.5]])
target = torch.tensor([1, -1], dtype=torch.float)
output = loss_f(inputs_1,inputs_2,target)

print('CosineEmbeddingLoss损失函数的计算结果为',output)
# Out:
# CosineEmbeddingLoss损失函数的计算结果为 tensor(0.5000)

# %% [markdown]
# 其他损失函数[https://datawhalechina.github.io/thorough-pytorch/%E7%AC%AC%E4%B8%89%E7%AB%A0/3.6%20%E6%8D%9F%E5%A4%B1%E5%87%BD%E6%95%B0.html#l1]
